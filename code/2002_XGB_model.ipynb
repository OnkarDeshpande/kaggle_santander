# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import ensemble
from scipy.stats import spearmanr

import time
import warnings
warnings.filterwarnings("ignore")

import xgboost as xgb
# from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import StratifiedKFold

import utils

# %%
df_train = pd.read_csv('../data/train.csv')
target = df_train.pop('target')

df_train.drop(['ID_code'], axis=1, inplace=True)

# %%
test_file = '../data/test.csv'

df_test = pd.read_csv(test_file)
test_id = df_test.pop('ID_code')

# %%
params = {
        'max_depth': 6,
        'colsample_bytree': 0.3,
        'learning_rate': 0.01,
        'objective': 'binary:logistic',
        'eval_metric' : 'auc',
        'subsample': 0.5,
        'n_jobs': 8    
        }

# %%
# %%time
fold_n = 5

folds = StratifiedKFold(n_splits = fold_n, shuffle=True, random_state=30)
y_pred_xgb = np.zeros(len(df_test))

for fold_n, (train_index, valid_index) in enumerate(folds.split(df_train, target)):
    print('Fold', fold_n, 'started at', time.ctime())

    dtrain = xgb.DMatrix(df_train.iloc[train_index], label=target.iloc[train_index])
    dvalid = xgb.DMatrix(df_train.iloc[valid_index], label=target.iloc[valid_index])

    evallist = [(dtrain, 'train'), (dvalid, 'eval')]
    xgb_model = xgb.train( params, dtrain, num_boost_round = 5000,
                      evals = evallist, verbose_eval=300, early_stopping_rounds=200)

    

    y_pred_xgb += xgb_model.predict(xgb.DMatrix(df_test), ntree_limit=xgb_model.best_ntree_limit)/fold_n
# Out:
# Fold 0 started at Wed Mar  6 03:46:21 2019
# [0]	train-auc:0.610269	eval-auc:0.611468
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 200 rounds.
# [300]	train-auc:0.865255	eval-auc:0.824235
# [600]	train-auc:0.908248	eval-auc:0.856637
# [900]	train-auc:0.932121	eval-auc:0.873129
# [1200]	train-auc:0.946429	eval-auc:0.882266
# [1500]	train-auc:0.956497	eval-auc:0.887872
# [1800]	train-auc:0.963834	eval-auc:0.891435
# [2100]	train-auc:0.969633	eval-auc:0.893996
# [2400]	train-auc:0.974105	eval-auc:0.895711
# [2700]	train-auc:0.977761	eval-auc:0.897128
# [3000]	train-auc:0.980848	eval-auc:0.898145
# [3300]	train-auc:0.983401	eval-auc:0.898606
# [3600]	train-auc:0.985625	eval-auc:0.899218
# [3900]	train-auc:0.987527	eval-auc:0.899694
# [4200]	train-auc:0.989197	eval-auc:0.899906
# [4500]	train-auc:0.990675	eval-auc:0.900207
# [4800]	train-auc:0.991893	eval-auc:0.900423
# [4999]	train-auc:0.992632	eval-auc:0.900544
# Fold 1 started at Wed Mar  6 04:12:31 2019
# [0]	train-auc:0.616655	eval-auc:0.612626
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 200 rounds.
# [300]	train-auc:0.865498	eval-auc:0.816443
# [600]	train-auc:0.908764	eval-auc:0.848805
# [900]	train-auc:0.933124	eval-auc:0.865593
# [1200]	train-auc:0.947372	eval-auc:0.874623
# [1500]	train-auc:0.957076	eval-auc:0.880466
# [1800]	train-auc:0.964332	eval-auc:0.884579
# [2100]	train-auc:0.96984	eval-auc:0.887181
# [2400]	train-auc:0.97425	eval-auc:0.889001
# [2700]	train-auc:0.977883	eval-auc:0.890313
# [3000]	train-auc:0.980921	eval-auc:0.891342
# [3300]	train-auc:0.983576	eval-auc:0.892144
# [3600]	train-auc:0.985778	eval-auc:0.892678
# [3900]	train-auc:0.987661	eval-auc:0.892975
# [4200]	train-auc:0.989301	eval-auc:0.893437
# [4500]	train-auc:0.990744	eval-auc:0.893671
# [4800]	train-auc:0.992016	eval-auc:0.893728
# [4999]	train-auc:0.992734	eval-auc:0.893732
# Fold 2 started at Wed Mar  6 04:37:47 2019
# [0]	train-auc:0.603184	eval-auc:0.590791
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 200 rounds.
# [300]	train-auc:0.865527	eval-auc:0.817669
# [600]	train-auc:0.90865	eval-auc:0.851588
# [900]	train-auc:0.932616	eval-auc:0.868464
# [1200]	train-auc:0.947217	eval-auc:0.878511
# [1500]	train-auc:0.956862	eval-auc:0.884521
# [1800]	train-auc:0.964085	eval-auc:0.888626
# [2100]	train-auc:0.969668	eval-auc:0.89128
# [2400]	train-auc:0.974089	eval-auc:0.893163
# [2700]	train-auc:0.977752	eval-auc:0.894442
# [3000]	train-auc:0.980865	eval-auc:0.895738
# [3300]	train-auc:0.983388	eval-auc:0.896459
# [3600]	train-auc:0.985565	eval-auc:0.896962
# [3900]	train-auc:0.987467	eval-auc:0.897315
# [4200]	train-auc:0.989091	eval-auc:0.897583
# [4500]	train-auc:0.990529	eval-auc:0.897916
# [4800]	train-auc:0.991759	eval-auc:0.898087
# [4999]	train-auc:0.992501	eval-auc:0.898216
# Fold 3 started at Wed Mar  6 05:02:53 2019
# [0]	train-auc:0.619696	eval-auc:0.603934
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 200 rounds.
# [300]	train-auc:0.864544	eval-auc:0.815162
# [600]	train-auc:0.908861	eval-auc:0.847597
# [900]	train-auc:0.93275	eval-auc:0.864965
# [1200]	train-auc:0.94684	eval-auc:0.87463
# [1500]	train-auc:0.956769	eval-auc:0.880971
# [1800]	train-auc:0.963946	eval-auc:0.885066
# [2100]	train-auc:0.969594	eval-auc:0.88826
# [2400]	train-auc:0.9741	eval-auc:0.890546
# [2700]	train-auc:0.977808	eval-auc:0.892013
# [3000]	train-auc:0.980901	eval-auc:0.893073
# [3300]	train-auc:0.983545	eval-auc:0.893908
# [3600]	train-auc:0.985787	eval-auc:0.894483
# [3900]	train-auc:0.987676	eval-auc:0.894936
# [4200]	train-auc:0.989377	eval-auc:0.895236
# [4500]	train-auc:0.990837	eval-auc:0.895434
# [4800]	train-auc:0.992135	eval-auc:0.895661
# [4999]	train-auc:0.992837	eval-auc:0.895841
# Fold 4 started at Wed Mar  6 05:56:19 2019
# [0]	train-auc:0.617325	eval-auc:0.606843
# Multiple eval metrics have been passed: 'eval-auc' will be used for early stopping.
#
# Will train until eval-auc hasn't improved in 200 rounds.
# [300]	train-auc:0.863336	eval-auc:0.813963
# [600]	train-auc:0.909142	eval-auc:0.847992
# [900]	train-auc:0.932854	eval-auc:0.86567
# [1200]	train-auc:0.947146	eval-auc:0.875635
# [1500]	train-auc:0.956795	eval-auc:0.881741
# [1800]	train-auc:0.963978	eval-auc:0.886265
# [2100]	train-auc:0.969522	eval-auc:0.889288
# [2400]	train-auc:0.974032	eval-auc:0.891314
# [2700]	train-auc:0.977628	eval-auc:0.892787
# [3000]	train-auc:0.980704	eval-auc:0.893899
# [3300]	train-auc:0.983301	eval-auc:0.894598
# [3600]	train-auc:0.985498	eval-auc:0.895347
# [3900]	train-auc:0.987477	eval-auc:0.89583
# [4200]	train-auc:0.989152	eval-auc:0.896245
# [4500]	train-auc:0.990658	eval-auc:0.896531
# [4800]	train-auc:0.991954	eval-auc:0.896748
# [4999]	train-auc:0.992742	eval-auc:0.896822
# CPU times: user 20h 58min 34s, sys: 53.4 s, total: 20h 59min 27s
# Wall time: 2h 53min 17s

# %%
submission_xgb = pd.DataFrame({
        "ID_code": test_id,
        "target": y_pred_xgb
    })
submission_xgb.to_csv('../results/submission_xgb.csv', index=False)

# %%
##benchmarks and things to try
# Here we go in terms of CV

# LightGBM            0.89804
# XGBoost             0.89712
# FeedForward Net     0.87236
# Logistic Regression 0.89096

# https://www.kaggle.com/bogorodvo/starter-code-saving-and-loading-lgb-xgb-cb/output

# %%
# why insight
# your background
# career goals
