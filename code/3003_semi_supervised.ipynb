# %% [markdown]
# # Semi-supervised Learning
#
# Extensive tutorial:
#
# https://nbviewer.jupyter.org/github/Yorko/mlcourse.ai/blob/master/jupyter_english/tutorials/basic_semi-supervised_learning_models_altprof.ipynb
#
#
# Inspired from the discussion:
#
# https://www.kaggle.com/c/santander-customer-transaction-prediction/discussion/81012

# %%
import numpy as np
import pandas as pd

import seaborn as sns
sns.set_style('whitegrid')

import time

import lightgbm as lgb

from sklearn.model_selection import KFold,StratifiedKFold
from sklearn.model_selection import GridSearchCV

from sklearn.semi_supervised import LabelPropagation, LabelSpreading

# %%
train_file = '../data/train.csv'
test_file = '../data/test.csv'

df_train = pd.read_csv(train_file)
df_test = pd.read_csv(test_file)

np.random.seed(42)

# %%
##create data
df_train.drop(['ID_code'], axis=1, inplace=True)
df_test.drop(['ID_code'], axis=1, inplace=True)

df_test['target'] = -1
df_data = pd.concat([df_train[:150000], df_test[:50000]], sort=False)

df_data.reset_index(drop=True, inplace=True)

# %%
y=df_data.pop('target')

# %%
df_data.tail()
# Out:
#           var_0   var_1    var_2    var_3    var_4   var_5   var_6    var_7  \
# 249995   7.0240 -0.6464   7.5908   6.8304   9.2120  0.2706  5.2137  14.0363
# 249996  12.3166  4.1965  10.4970   7.2551  10.2213 -4.5510  5.9518  11.9121
# 249997  12.6349 -5.1270  10.4343  10.1780  11.7115 -6.5469  6.3498  15.3994
# 249998  14.9537 -7.7702   7.9673   6.1516  11.7081  5.1827  6.0146  16.0186
# 249999   6.7936 -4.8525   7.3744   6.5287   8.8231  0.9771  4.4529  10.3753
#
#          var_8   var_9   ...     var_190  var_191  var_192  var_193  var_194  \
# 249995 -2.2202  8.2531   ...      6.5885   8.8469  -0.2717   8.5653  11.9406
# 249996 -2.3536  7.5047   ...     -0.8419  10.3713   2.2906   2.2353  12.4251
# 249997 -3.3625  9.1159   ...      6.1733  10.8918   0.2253  -0.1206  22.1757
# 249998  1.9084  5.8987   ...      2.3368  13.6903   2.9851   2.1926  17.9028
# 249999  7.2619  6.9143   ...      4.0419   9.5608   4.1339  -0.7707  13.0548
#
# ...

# %%
lp_rbf = LabelPropagation(kernel='rbf', gamma=9e-6, max_iter=10000, tol=0.0001)
lp_rbf.fit(df_data, y)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-91e1dd893da5> in <module>
#       1 lp_rbf = LabelPropagation(kernel='rbf', gamma=9e-6, max_iter=10000, tol=0.0001)
# ----> 2 lp_rbf.fit(df_data, y)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/semi_supervised/label_propagation.py in fit(self, X, y)
#     417             )
#     418             self.alpha = None
# --> 419         return super(LabelPropagation, self).fit(X, y)
#     420
#     421
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/semi_supervised/label_propagation.py in fit(self, X, y)
#     231
#     232         # actual graph construction (implementations should override this)
# --> 233         graph_matrix = self._build_graph()
#     234
#     235         # label construction
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/semi_supervised/label_propagation.py in _build_graph(self)
# ...
